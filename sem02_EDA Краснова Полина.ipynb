# %% [markdown]
# # Разведочный анализ данных (Exploratory Data Analysis)
#
# На семинаре продолжим работать с данными о пассажирах Титаника.
#
# Цели:
# * познакомиться с библиотекой seaborn
# * научиться делать различные визуализации
# * заполнять пропуски в данных
# * делать однофакторный анализ
# * строить простую предсказательную модель
#
#
# * (бонус) конструировать новые признаки
#
# Основы matplotlib: https://devpractice.ru/matplotlib-lesson-1-quick-start-guide/

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Загрузим данные.

# %%
Data = pd.read_csv("https://raw.githubusercontent.com/iad34/seminars/master/materials/data_sem1.csv",
                   sep=";")

# %% [markdown]
# **Задание 1.** Выведите на экран размеры таблицы

# %%
Data.shape
# Out:
# (891, 12)

# %% [markdown]
# # Обработка признаков и однофакторный анализ
#
# 1) Найдем признаки, у которых есть пропущенные значения и обработаем эти пропущенные значения
#
# 2) Переведём категориальные признаки в числовые

# %% [markdown]
# **Задание 2.** Выведите основные числовые характеристики числовых столбцов.

# %%
Data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
Data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund; Mr. Owen Harris    male  22.0      1
# 1  Cumings; Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen; Miss. Laina  female  26.0      0
# 3       Futrelle; Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen; Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Функция не позволяет увидеть наличие пропусков в нечисловых столбцах.
#
# **Обработаем признак 'Sex'**
#
# **Задание 3.** Проверьте, есть ли пропуски в столбце.

# %%
Data['Sex'].value_counts()
# Out:
# male       574
# female     312
# unknown      5
# Name: Sex, dtype: int64

# %% [markdown]
# **Задание 4.** Удалите пассажиров неизвестного пола, так как их всего 5.

# %%
Data = Data[Data.Sex != 'unknown']
Data.shape
# Out:
# (886, 12)

# %% [markdown]
# Признак 'Sex' является категориальным, то есть содержит нечисловые значения. Для работы большинства алгоритмов необходимо переводить категории в числа. Как это можно сделать?
#
# **Задание 5.** Придумайте кодировку и сделайте её.

# %%
Data['Sex'] = Data['Sex'].apply(lambda x: 1 if x == 'male' else 0)
Data.Sex
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# Name: Sex, Length: 886, dtype: int64

# %% [markdown]
# Посмотрим, как влияет пол на выживаемость.

# %%
Data.head()

# %%
sns.barplot(x='Sex', y='Survived', data=Data, palette='summer')
plt.title('Sex - Survived')
plt.show()

# %% [markdown]
# Посмотрим, как влияет пол человека и класс билета (Pclass) на выживаемость

# %%
sns.barplot(x='Sex', y='Survived', hue='Pclass', data=Data, palette='autumn')
plt.title('Sex - Survived')
plt.show()

# %% [markdown]
# Ещё один полезный вид визуализации - ящик с усами. Посмотрим на ящик с усами, отражающий распределение пассажиров по полу и возрасту.

# %%
sns.factorplot(x="Sex", y="Age", data=Data, kind="box") # box plot (box-and-whiskers-plot)
plt.show()
# Out:
# C:\Users\polin\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# Можно детализировать картинку, добавив разделение по Pclass.

# %%
sns.factorplot(x="Sex", y="Age",hue ="Pclass", data=Data, kind="box")
plt.show()
# Out:
# C:\Users\polin\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# **Обработаем признак 'Embarked'**

# %%
print(Data['Embarked'].value_counts(dropna=False))
Data.shape
# Out:
# S      641
# C      168
# Q       75
# NaN      2
# Name: Embarked, dtype: int64
# (886, 12)

# %% [markdown]
# **Задание 6.** Удалите из таблицы пассажиров, для которых неизвестен порт посадки (Embarked).

# %%
Data.dropna(subset=['Embarked'], inplace=True)

# %%
Data.shape
# Out:
# (884, 12)

# %% [markdown]
# **Задание 7.** Удалите из таблицы Data столбец Embarked.

# %%
Data.drop('Embarked', axis=1, inplace=True)

# %%
Data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund; Mr. Owen Harris    1  22.0      1      0
# 1  Cumings; Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen; Miss. Laina    0  26.0      0      0
# 3       Futrelle; Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen; Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin
# 0         A/5 21171   7.2500   NaN
# 1          PC 17599  71.2833   C85
# 2  STON/O2. 3101282   7.9250   NaN
# 3            113803  53.1000  C123
# 4            373450   8.0500   NaN

# %% [markdown]
# **Обработаем признак 'Age'**
#
# Проверьте, если ли в Age пропущенные значения.

# %%
#your code here

# %% [markdown]
# Заполним пропуски медианным значением Age.

# %%
median_age = Data['Age'].median()

Data['Age'].fillna(median_age, inplace=True)

# %% [markdown]
# Нарисуем распределение возраста пассажиров.

# %%
sns.distplot(Data['Age'], kde=True)
plt.show()
# Out:
# C:\Users\polin\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Посмотрим на распределение Pclass по возрастам.

# %%
import seaborn as sns

facet = sns.FacetGrid(data = Data, hue = "Pclass", legend_out=True, size = 5)
facet = facet.map(sns.kdeplot, "Age")
facet.add_legend();
# Out:
# C:\Users\polin\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# **Обработаем признак 'Fare'**
#
# 1) Проверим, если ли в Fare пропущенные значения
#
# 2) Если пропущенные значения есть, заполним их медианным значением Fare

# %%
Data['Fare'].value_counts()
# Out:
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 8.3000      1
# 13.7917     1
# 14.1083     1
# 9.8375      1
# 17.4000     1
# Name: Fare, Length: 246, dtype: int64

# %% [markdown]
# **Обработаем признак 'Pclass'**

# %%
Data['Pclass'].value_counts()
# Out:
# 3    487
# 1    214
# 2    183
# Name: Pclass, dtype: int64

# %%
Data['Pclass'].isna().sum()
# Out:
# 0

# %% [markdown]
# **Задание 8.** Нарисуйте гистограмму выживаемости в зависимости от Pclass.

# %%
sns.barplot(x='Pclass', y='Survived', data=Data, palette='winter')
plt.title('Pclass - Survived')
plt.show()

# %% [markdown]
# Столбец PassengerId является категориальным и не несёт важной информации, удалим его.

# %%
Data.drop('PassengerId',axis=1,inplace=True)

# %%
Data.head()
# Out:
#    Survived  Pclass                                               Name  Sex  \
# 0         0       3                            Braund; Mr. Owen Harris    1
# 1         1       1  Cumings; Mrs. John Bradley (Florence Briggs Th...    0
# 2         1       3                             Heikkinen; Miss. Laina    0
# 3         1       1       Futrelle; Mrs. Jacques Heath (Lily May Peel)    0
# 4         0       3                           Allen; Mr. William Henry    1
#
#     Age  SibSp  Parch            Ticket     Fare Cabin
# 0  22.0      1      0         A/5 21171   7.2500   NaN
# 1  38.0      1      0          PC 17599  71.2833   C85
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3  35.0      1      0            113803  53.1000  C123
# 4  35.0      0      0            373450   8.0500   NaN

# %% [markdown]
# # Исследование признаков и feature engineering

# %% [markdown]
# Нарисуем матрицу корреляций числовых признаков между собой и с целевой переменной.
#
# Создадим таблицу NumericData, которая содержит только числовые столбцы из таблицы Data.

# %%
NumericData = Data._get_numeric_data()
NumericData.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare
# 0         0       3    1  22.0      1      0   7.2500
# 1         1       1    0  38.0      1      0  71.2833
# 2         1       3    0  26.0      0      0   7.9250
# 3         1       1    0  35.0      1      0  53.1000
# 4         0       3    1  35.0      0      0   8.0500

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(14,12))

plt.title('Pearson Correlation of Features', y=1.05, size=18)
sns.heatmap(NumericData.corr(),
            linewidths=0.1, vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <AxesSubplot:title={'center':'Pearson Correlation of Features'}>

# %% [markdown]
# Посмотрим на попарные зависимости некоторых признаков.

# %%
g = sns.pairplot(Data[[u'Survived', u'Pclass', u'Sex', u'Age', u'Parch', u'Fare']], \
                 hue='Survived', palette = 'seismic', size=4, diag_kind = 'kde', \
                 diag_kws=dict(shade=True), plot_kws=dict(s=50) )
g.set(xticklabels=[])
# Out:
# C:\Users\polin\anaconda3\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Получение простого предсказания.
#
# Мы видим, что больше всего влияют на выживаемость пол и класс:
# * женщины, как правило, выживали
# * мужчины, да ещё небогатые - нет
# * больше погибших, чем выживших

# %%
def first_prediction(x):
    if x.Sex == 0:
        return 1
    if x.Sex == 1 and x.Pclass > 1:
        return 0
    return 0

# %%
Data['prediction'] = Data.apply(lambda x: first_prediction(x), axis=1)
Data[['Survived','prediction']]
# Out:
#      Survived  prediction
# 0           0           0
# 1           1           1
# 2           1           1
# 3           1           1
# 4           0           0
# ..        ...         ...
# 886         0           0
# 887         1           1
# 888         0           1
# 889         1           0
# 890         0           0
#
# [884 rows x 2 columns]

# %% [markdown]
# Посмотрим на качество нашего предсказания.

# %%
from sklearn.metrics import accuracy_score

accuracy_score(Data['Survived'], Data['prediction'])
# Out:
# 0.7873303167420814

# %% [markdown]
# ## Бонусная часть - домашнее задание (+1 балл к итоговой оценке).

# %% [markdown]
# Зачастую признак может быть зашумлен или может содержать лишнюю (слишком детализированную, ведущую к переобучению) информацию. Возможным решением этой проблемы служит бинаризация признака.
#
# Бинаризуем признаки Age и Fare
#
# * pd.cut - разбиение целочисленных данных на несколько интервалов по квантилям
# * pd.qcut - разбиение числовых (не обязательно целочисленных) данных на несколько интервалов по квантилям

# %%
Data['AgeBin'] = pd.cut(Data['Age'].astype(int), 5)

Data['AgeBin'].head()
# Out:
# 0    (16.0, 32.0]
# 1    (32.0, 48.0]
# 2    (16.0, 32.0]
# 3    (32.0, 48.0]
# 4    (32.0, 48.0]
# Name: AgeBin, dtype: category
# Categories (5, interval[float64]): [(-0.08, 16.0] < (16.0, 32.0] < (32.0, 48.0] < (48.0, 64.0] < (64.0, 80.0]]

# %% [markdown]
# Теперь переведём полученные интервалы в числа, используя LabelEncoder. Полученные метки уже можно использовать как числовые признаки.

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

Data['AgeBin_Code'] = label.fit_transform(Data['AgeBin'])

Data[['Age','AgeBin','AgeBin_Code']].head()
# Out:
#     Age        AgeBin  AgeBin_Code
# 0  22.0  (16.0, 32.0]            1
# 1  38.0  (32.0, 48.0]            2
# 2  26.0  (16.0, 32.0]            1
# 3  35.0  (32.0, 48.0]            2
# 4  35.0  (32.0, 48.0]            2

# %% [markdown]
# **Задание 9.** Бинаризуйте Fare, используя разбиение на 4 интервала.

# %%
Data['FareBin'] = pd.qcut(Data['Fare'], 4)

Data['FareBin'].head()
# Out:
# 0    (-0.001, 7.896]
# 1    (31.0, 512.329]
# 2    (7.896, 14.454]
# 3    (31.0, 512.329]
# 4    (7.896, 14.454]
# Name: FareBin, dtype: category
# Categories (4, interval[float64]): [(-0.001, 7.896] < (7.896, 14.454] < (14.454, 31.0] < (31.0, 512.329]]

# %%
label1 = LabelEncoder()

Data['FareBin_Code'] = label1.fit_transform(Data['FareBin'])

Data[['Fare','FareBin','FareBin_Code']].head()
# Out:
#       Fare          FareBin  FareBin_Code
# 0   7.2500  (-0.001, 7.896]             0
# 1  71.2833  (31.0, 512.329]             3
# 2   7.9250  (7.896, 14.454]             1
# 3  53.1000  (31.0, 512.329]             3
# 4   8.0500  (7.896, 14.454]             1

# %% [markdown]
# Мы не используем всю информацию о данных, в частности, не используем текстовые данные. Также из матрицы корреляций мы видим, что признаки Parch и SibSp слабо коррелируют с выживаемостью (Survived). Сконструируем новые признаки, чтобы решить эти вопросы.
#
# **Задание 10.**
#
# 1) Создайте признак 'NameLen' и запишите в него длину имени (Name).
#
# 2) Создайте признак 'FamilySize', равный Parch + SibSp + 1. Зачем добавлять 1?
#
# 3) Создайте признак 'IsAlone', который показывает, путешествовал человек один или с семьей.

# %%
#1
def namelen(name):
    counter = 0;
    for n in name:
        counter += n.isalpha()
    return counter

Data['NameLen'] = Data.apply(lambda x: namelen(x.Name), axis=1)

#2
Data['FamilySize'] = Data.apply(lambda x: x.Parch + x.SibSp + 1, axis=1)

#3
Data['IsAlone'] = Data.apply(lambda x: 1 if x.FamilySize == 1 else 0 , axis=1)

Data.head()
# Out:
#    Survived  Pclass                                               Name  Sex  \
# 0         0       3                            Braund; Mr. Owen Harris    1
# 1         1       1  Cumings; Mrs. John Bradley (Florence Briggs Th...    0
# 2         1       3                             Heikkinen; Miss. Laina    0
# 3         1       1       Futrelle; Mrs. Jacques Heath (Lily May Peel)    0
# 4         0       3                           Allen; Mr. William Henry    1
#
#     Age  SibSp  Parch            Ticket     Fare Cabin  prediction  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN           0
# 1  38.0      1      0          PC 17599  71.2833   C85           1
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN           1
# 3  35.0      1      0            113803  53.1000  C123           1
# 4  35.0      0      0            373450   8.0500   NaN           0
#
#          AgeBin  AgeBin_Code          FareBin  FareBin_Code  NameLen  \
# 0  (16.0, 32.0]            1  (-0.001, 7.896]             0       18
# 1  (32.0, 48.0]            2  (31.0, 512.329]             3       41
# 2  (16.0, 32.0]            1  (7.896, 14.454]             1       18
# 3  (32.0, 48.0]            2  (31.0, 512.329]             3       34
# 4  (32.0, 48.0]            2  (7.896, 14.454]             1       19
#
#    FamilySize  IsAlone  second_prediction  IsChild
# 0           2        0                  0        0
# 1           2        0                  1        0
# 2           1        1                  1        0
# 3           2        0                  1        0
# 4           1        1                  0        0

# %% [markdown]
# **Задание 11**. Выведите на экран визуализации, отражающие влияние новых созданных признаков на целевую переменную (Survived). Тип визуализации остается на ваше усмотрение.

# %%
# 1
sns.barplot(x='FamilySize', y='Survived', data=Data, palette='spring')
plt.title('FamilySize - Survived')
plt.show()

# %%
# 2
plt.figure(figsize=(15, 10))
sns.barplot(x='NameLen', y='Survived', data=Data, palette='BuPu')
plt.title('NameLen - Survived')
plt.show()

# %%
# 3
sns.barplot(x='IsAlone', y='Survived', data=Data, palette='Accent')
plt.title('IsAlone - Survived')
plt.show()

# %% [markdown]
# **Задание 12.** Посмотрите, как коррелируют новые признаки (не забудьте про бинаризованные признаки) со столбцом 'Survived'.

# %%
colormap = plt.cm.GnBu
plt.figure(figsize=(14,12))

plt.title('Pearson Correlation of Features', y=1.05, size=18)
sns.heatmap(Data[['Survived','NameLen', 'FamilySize', 'IsAlone', 'FareBin_Code', 'AgeBin_Code']].corr(),
            linewidths=0.1, vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <AxesSubplot:title={'center':'Pearson Correlation of Features'}>

# %%
# Видно, что из новых признаков больше всего на выживаемость влияют NameLen, IsAlone и FareBin_Code

# %% [markdown]
# Можно извлечь и другую полезную информацию из данных путём конструирования новых признаков.
#
# **Задание 13*.** Придумайте ещё новые осмысленные признаки. Проверьте, как они коррелируют с выживаемостью. Визуализируйте влияние новых признаков на целевую переменную.

# %%
# Например, является ли человек ребенком?
# Проверяем есть ли семья (обычно дети не путешествуют одни) и маленький возраст
Data['IsChild'] = Data.apply(lambda x: 1 if x.FamilySize > 1 and x.Age < 15 else 0 , axis=1)

sns.barplot(x='IsChild', y='Survived', data=Data, palette='pastel')
plt.title('IsChild - Survived')
plt.show()

# Как видим, дети выживали чаще

# %% [markdown]
# **Задание 14.** Верно ли, что если признак имеет маленькую по модулю корреляцию с выживаемостью, то это означает, что он не влияет на выживаемость и бесполезен для нашей задачи?

# %%
# Мне кажется, использование одного такого признака не сильно поможет в задаче, но выживаемость от него все же зависит.
# Можно посмотреть, как влияет на выживаемость комбинация таких признаков, и попробовать вывести новый более сильный признак.
# По результатам 12 задания видно, что признаки FamilySize и AgeBin_Code меньше других коррелируют с выживаемостью.
# Посмотрим, как они вместе влияют на выживаемость.
sns.barplot(x='Survived', y='FamilySize', hue='AgeBin_Code', data=Data, palette='autumn')
plt.title('FamilySize/AgeBin_Code - Survived')
plt.show()

# Из графика видно, что люди с AgeBin_Code = 0 и семьей из более 2 человек погибали намного чаще остальных.
# Использование этого признака действительно улучшило предсказание на 0,8%

# %% [markdown]
# **Задание 15.** Попробуйте улучшить предсказание нашей модели, используя, кроме признаков Sex и Pclass другие признаки.

# %%
def second_prediction(x):
    if x.FamilySize > 4 and x.AgeBin_Code == 0:
        return 0
    if x.IsAlone == 0 and x.FareBin_Code == 3 and x.AgeBin_Code == 4 and x.IsChild == 0:
        return 0
    if x.Sex == 0:
        if x.Pclass > 2 and x.IsAlone == 0 and x.FamilySize > 4:
            return 0
        else:
            return 1
    if x.Sex == 1:
        if x.IsAlone == 0 and x.AgeBin_Code < 4 and x.FareBin_Code < 3 and x.IsChild == 1:
            return 1
        else:
            return 0
        
    return 0

# %%
Data['second_prediction'] = Data.apply(lambda x: second_prediction(x), axis=1)
Data[['Survived','second_prediction']]
# Out:
#      Survived  second_prediction
# 0           0                  0
# 1           1                  1
# 2           1                  1
# 3           1                  1
# 4           0                  0
# ..        ...                ...
# 886         0                  0
# 887         1                  1
# 888         0                  1
# 889         1                  0
# 890         0                  0
#
# [884 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score

accuracy_score(Data['Survived'], Data['second_prediction'])

# Качество предсказания примерно 82,5%
# Out:
# 0.8257918552036199
